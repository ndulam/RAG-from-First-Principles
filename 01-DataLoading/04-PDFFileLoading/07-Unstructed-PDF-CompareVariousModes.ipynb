# %%
from unstructured.partition.pdf import partition_pdf

# Specify the file path
file_path = "/home/huangj2/Documents/20250202_RAG_Book/data/Shanxi Cultural Tourism/Yungang Grottoes-en.pdf"

# Parse the PDF
elements = partition_pdf(filename=file_path)

# Show the parsed content
for i, element in enumerate(elements[:10]):  # only show the first 10 elements
    print(f"Element {i+1}:")
    print(element)
    print("-" * 80)

# %%
from unstructured.partition.pdf import partition_pdf

# Specify the file path
file_path = "/home/huangj2/Documents/20250202_RAG_Book/data/Shanxi Cultural Tourism/Yungang Grottoes-en.pdf"

# Parse the PDF
elements = partition_pdf(
    filename=file_path,
    strategy="hi_res",  # use high-precision mode; the regular mode is fast
    chunking_strategy="by_title",  # chunk by title; the regular mode is Basic
    max_characters=2500,  # maximum characters per chunk
    new_after_n_chars=2300,  # start a new chunk after reaching this many characters
    infer_table_structure=True,  # infer table structure
    extract_images=True,  # extract images
    image_format="png",  # image format
    include_metadata=True  # include metadata
)

# Show the parsed elements
for i, element in enumerate(elements):
    print(f"Element {i+1}:")
    print(element)
    print("-" * 80)

# %%
# Show each element's content and metadata
for i, element in enumerate(elements):
    print(f"Element {i+1}:")
    print("Content:", element.text)  # print the element's text content
    print("Metadata:", element.metadata.to_dict())  # print the element's metadata
    print("-" * 80)

# %%
from unstructured.partition.pdf import partition_pdf

# Specify the file path
file_path = "/home/huangj2/Documents/20250202_RAG_Book/data/Shanxi Cultural Tourism/Yungang Grottoes-en.pdf"

# Parse the PDF
elements = partition_pdf(
    filename=file_path,
    strategy="hi_res",  # use high-precision mode; the regular mode is fast
    chunking_strategy="basic",  # chunk by title; the regular mode is Basic
    max_characters=500,  # maximum characters per chunk
    new_after_n_chars=300,  # start a new chunk after reaching this many characters
    infer_table_structure=True,  # infer table structure
    extract_images=True,  # extract images
    image_format="png",  # image format
    include_metadata=True  # include metadata
)

# Show the parsed elements
for i, element in enumerate(elements):
    print(f"Element {i+1}:")
    print(element)
    print("Metadata:", element.metadata.to_dict())  # print the element's metadata
    print("-" * 80)

# %%
# Print each element's metadata
for element in elements:
    print(element.metadata.to_dict())

# %% [markdown]
# ## Comparing different Chunking Strategies

# %%
from unstructured.partition.pdf import partition_pdf

# Specify the file path
file_path = "/home/huangj2/Documents/20250202_RAG_Book/data/Shanxi Cultural Tourism/Yungang Grottoes-en.pdf"

# Parse the PDF
elements = partition_pdf(
    filename=file_path,
    strategy="hi_res",  # use high-precision mode; the regular mode is Fast
    # chunking_strategy="basic",  # chunk by title; the regular mode is Basic
    max_characters=500,  # maximum characters per chunk
    new_after_n_chars=300,  # start a new chunk after reaching this many characters
    infer_table_structure=True,  # infer table structure
    extract_images=True,  # extract images
    image_format="png",  # image format
    include_metadata=True  # include metadata
)

# Show the parsed elements
for i, element in enumerate(elements):
    print(f"Element {i+1}:")
    print(element)
    print("Metadata:", element.metadata.to_dict())  # print the element's metadata
    print("-" * 80)

# %%
from unstructured.partition.pdf import partition_pdf

# Specify the file path
file_path = "/home/huangj2/Documents/20250202_RAG_Book/data/BlackMythWukong/black mythWukong.pdf"

# Parse the PDF
elements = partition_pdf(
    filename=file_path,
    strategy="fast",  # use high-precision mode; the regular mode is fast
    # chunking_strategy="basic",  # chunk by title; the regular mode is Basic
    # max_characters=500,  # maximum characters per chunk
    # new_after_n_chars=300,  # start a new chunk after reaching this many characters
    # infer_table_structure=True,  # infer table structure
    # extract_images=True,  # extract images
    # image_format="png",  # image format
    # include_metadata=True  # include metadata
)

# Show the parsed elements
for i, element in enumerate(elements):
    print(f"Element {i+1}:")
    print(element)
    print("Metadata:", element.metadata.to_dict())  # print the element's metadata
    print("-" * 80)

# %%
elements[0].to_dict()

# %%
elements[0].id

# %%
from unstructured.partition.pdf import partition_pdf

# Specify the file path
file_path = "/home/huangj2/Documents/20250202_RAG_Book/data/Shanxi Cultural Tourism/Yungang Grottoes-en.pdf"

# Parse the PDF
elements = partition_pdf(
    filename=file_path,
    strategy="hi_res",  # use high-precision mode; the regular mode is fast
    chunking_strategy="basic",  # chunk by title; the regular mode is Basic
    max_characters=500,  # maximum characters per chunk
    new_after_n_chars=300,  # start a new chunk after reaching this many characters
    infer_table_structure=True,  # infer table structure
    extract_images=True,  # extract images
    image_format="png",  # image format
    include_metadata=True  # include metadata
)

# Show the parsed elements
for i, element in enumerate(elements):
    print(f"Element {i+1}:")
    print(element)
    print("Metadata:", element.metadata.to_dict())  # print the element's metadata
    print("-" * 80)

# %%
from unstructured.partition.pdf import partition_pdf

# Specify the file path
file_path = "/home/huangj2/Documents/20250202_RAG_Book/data/Shanxi Cultural Tourism/Yungang Grottoes-en.pdf"

# Parse the PDF
elements = partition_pdf(
    filename=file_path,
    strategy="hi_res",  # use high-precision mode; the regular mode is fast
    chunking_strategy="by_title",  # chunk by title; the regular mode is Basic
    max_characters=500,  # maximum characters per chunk
    new_after_n_chars=300,  # start a new chunk after reaching this many characters
    infer_table_structure=True,  # infer table structure
    extract_images=True,  # extract images
    image_format="png",  # image format
    include_metadata=True  # include metadata
)

# Show the parsed elements
for i, element in enumerate(elements):
    print(f"Element {i+1}:")
    print(element)
    print("Metadata:", element.metadata.to_dict())  # print the element's metadata
    print("-" * 80)
